# %%
# %%capture
# !sudo apt-get update
# !sudo apt-get install -y swig
# Install the custom package for this course.
# !pip install "git+https://github.com/xrhd/mula.git@fix/main"

# %%
import mula
from mula import rl
